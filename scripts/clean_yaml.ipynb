# %% [markdown]
# # Purpose of this notebook
# We have `yaml` files retrieved from different sources and these files contain different names for the same entity. Ccategories need to be checked as well.
#
# This notebook creates a mapping from labels to unique labels (`label_uniqueLabel.json`) and a mapping from unique labels to the right categories (`uniqueLabel_category.json`).
#
# Every time a yaml file is created or added to the list, its labels must be mapped to unique labels and its categories to the right categories using these two `json` files.
#
# `config.yaml` is also updated with the new list of categories.

# %% [markdown]
# # Step \#1. Create a file mapping entity label to its category (skip blockchain.info)

# %%
import yaml
import json
from os import listdir

# %%
# for each yaml file
# get all the <label,category> pairs
label_category = dict() # initial (dirty) label-category mapping
packs_folder = '../packs/'
for file in listdir(packs_folder):
    if file != 'blockchaininfo.yaml' and file[-3:] != 'csv': # blockchaininfo has no categories
        print(file)
        with open(packs_folder + file) as fp:
            data = yaml.safe_load(fp)
        for el in data['tags']:
            if 'category' in el and 'label' in el:
                label_category[el['label'].lower()] = el['category']
            elif 'category' not in el and 'label' in el:
                label_category[el['label'].lower()] = data['category']
            elif 'category' in el and 'label' not in el:
                label_category[data['label'].lower()] = el['category']
            elif 'category' in data and 'label' in data:
                label_category[data['label'].lower()] = data['category']
# Out:
# walletexplorer.yaml
# richest_addresses.yaml
# ransomware.yaml
# binance.yaml
# binance_hack.yaml
# sextortion_talos.yaml
# miners.yaml
# demo.yaml
# sextortion_excello.yaml
# hacks.yaml
# ponzi_scheme.yaml

# %%
set(label_category.values())
# Out:
# {'Exchange',
#  'Gambling',
#  'Marketplace',
#  'Miner',
#  'Mixing Service',
#  'Other',
#  'Unspecified',
#  'Wallet Service'}

# %%
current_categories = set()
for lab, cat in label_category.items():
    if cat == '':
        print(lab)

# %% [markdown]
# ## Step #1a. Check uniqueness of labels

# %%
sorted_labels = [e.lower() for e in label_category.keys()]
sorted_labels.sort()

# %%
# merge all labels with same root (these were manually selected by looking at all the (sorted) dirty labels above)
labels_roots = ['cryptosplit', 'coindouble', '50btc', 'alphabaymarket', 'antpool', 'banx.io', 'betcoin.ag', 'bitaces', 'bitcoin-24.com', 'bitcoin.de', 'bitcoinica.com', 'bitcoinvideocasino.com', 'bitfinex', 'bitfury', 'bitminter', 'bitpay.com', 'bitstamp', 'bittrex', 'btc-e.com', 'btcc.com', 'btcjam.com', 'bter.com', 'btradeaustralia.com', 'c-cex.com', 'campbx.com', 'chainroll.com', 'cloudhashing', 'coinapult.com', 'coinroyale.com', 'cryptonator', 'cryptonit.net', 'cryptopay.me', 'cryptsy.com', 'deepbit', 'dgex.com', 'dmalocker', 'eclipsemc', 'eligius', 'foxbit.com.br', 'gatecoin.com', 'helixmixer', 'hitbtc.com', 'huobi.com', 'just-dice.com', 'kano', 'kncminer', 'kraken', 'leancy', 'localbitcoins.com', 'luckyb.it', 'okcoin.com', 'polmine', 'poloniex', 'primedice.com', 'satoshi-karoshi.com', 'satoshidice.com', 'securevpn.to', 'simplecoin.cz', 'slushpool', 'simplecoin', 'therocktrading.com', 'xapo', 'xlocker', 'zyado.com']

# %%
for l in sorted_labels:
    root_found = False
    for root in labels_roots:
        if l.startswith(root):
            root_found = True
            break
    if not root_found:
        print(l)
# Out:
# 10percentbtc
# 10xbitco.in
# 120cycle
# 175btc
# 1coin.com
# 1getpaid.me
# 1hash
# 1hourbtc.pw
# 21 inc.
# 58coin
# 777coin.com
# 796.com
# 7dayponzi
# 7ev3n
# 7pool
# 8baochi
# 999dice.com
# a-xbt
# abraxasmarket
# actioncrypto.com
# adamlocker
# admiralcoin.com
# agoramarket
# allcoin.com
# allcrypt.com
# alphabet
# angleware
# anonibet.com
# anxpro.com
# apt
# asicminer
# b2pool
# babylonmarket
# badblock
# badencrypt
# batpool
# bcmonster
# bcpool.io
# bestdoubler.eu
# betchain.com-old
# betco.in
# betco.in hack
# betcoin.tm
# betcoindice.tm
# betcoins.net
# betmoose.com
# betsofbitco.in
# binance
# binance hack
# bips
# bips hack
# birwo.com-old
# bit-x.com
# bitalo
# bitbargain.co.uk
# bitbay.net
# bitbond.com
# bitcash.cz
# bitcash.cz hack
# bitclix.com
# bitclub network
# bitcoin affiliate network
# bitcoin india
# bitcoin-roulette.com
# bitcoin-ukraine
# bitcoin.com
# bitcoincopy.site123.me
# bitcoindoubler.fund
# bitcoindoubler.prv.pl
# bitcoinfog
# bitcoinica hack
# bitcoinpokertables.com
# bitcoinprofit2
# bitcoinrussia
# bitcoinvietnam.com.vn
# bitcoinwallet.com
# bitcoinwebank.com
# bitcurex.com
# bitelfin.com
# bitfarms
# bitfloor
# bitfloor hack
# bitkonan.com
# bitlaunder.com
# bitmain
# bitmillions.com
# bitmit.net
# bitnz.com
# bitoex.com
# bitoomba.com
# bitparking
# bitso.com
# bitsolo
# bitstarz.com
# bitvc.com
# bityes.com
# bitzillions.com
# bitzino.com
# bixin
# blackbankmarket
# blackfeather
# bleutrade.com
# blocktrades.us
# blueskymarketplace
# bravo mining
# brawker.com
# btc nuggets
# btc pool party
# btc-doubler.com
# btc-doubler.us
# btc-flow
# btc.com
# btc.top
# btc38.com
# btcc pool
# btcdice.com
# btcdig
# btceur.eu
# btcexchange.ro
# btcgains
# btcguild.com
# btclend.org
# btcmarkets.net
# btcmp
# btcoracle.com
# btcpoolman
# btcpop.co
# btcserv
# btcst.com-pirateat40
# btct.com
# btctrade.com
# btcware
# bter hack
# btpool
# bucbi
# buddy
# bw.com
# bx.in.th
# bylls.com
# cannabisroadmarket
# canoe
# cavirtex.com
# ccedk.com
# cex.io
# changetip.com
# chbtc.com
# chimera
# clearhash.net
# clevercoin.com
# cloudbet.com
# coin-generator.net
# coin-swap.net
# coin-sweeper.com
# coin.mx
# coinarch.com
# coinbox.me
# coinbroker.io
# coincafe.com
# coincheck
# coinchimp.com
# coingaming.io
# coingi.com
# coinhako.com
# coinhub.cz
# coinichiwa.com
# coinimal.com
# coiniumserv
# coinjar.com
# coinkite.com
# coinlab
# coinmate.io
# coinmkt.com
# coinmotion.com
# coinomat.com
# coinpayments.net
# coinpool
# coinroll.com
# coins-e.com
# coinspot.com.au
# cointerra
# cointrader.net
# coinurl.com
# coinvault
# coinworker.com
# comkort.com
# comradecircle
# connectbtc
# cryptcominer.com
# cryptconsole
# crypto-games.net
# crypto-trade.com
# cryptobounty.com
# cryptohitman
# cryptohost
# cryptolocker
# cryptomine.io
# cryptorush.in
# cryptory
# cryptostocks.com
# cryptosweettooth
# cryptosx2
# cryptotorlocker2015
# cryptxxx
# ctb-locker
# cubits.com
# cybersplitter
# dadice.com
# dagensia.eu
# dcexploration
# dicebitco.in
# dicecoin.io
# dicenow.com
# diceoncrack.com
# digitalbtc
# dispenser.tf
# doctordmarket
# domino
# doublebitcoin.life
# doublebot
# doxware
# dpool
# dragonex hack
# ebitinvest.com
# eda2
# ekanembtc
# empoex.com
# eobot
# epay.info
# europex.eu
# everydice.com
# evolutionmarket
# exchange-credit.ru
# exchangemycoins.com
# exchanging.ir
# exmo.com
# exotic
# f2pool
# fairproof.com
# fakeglobe
# fantom
# faucetbox.com
# firecrypt
# flexcoin
# flexcoin hack
# flyper
# fortunejack.com
# fybsg.com
# gbminers
# genesis-mining.com
# germanplazamarket
# ghash.io
# globe
# globeimposter
# gocelery.com
# gogreenlight
# grandagofinance
# greenroadmarket
# haobtc.com
# haozhuzhu
# happycoins.com
# hashnest.com
# hhtt
# holytransaction.com
# hotpool
# huobi mining pool
# ice-dice.com
# icedrill
# igjam.com
# igot.com
# indacoin.com
# inputs.io
# inputs.io hack
# instawallet.org
# internet archive
# invest4profit
# investorbitcoin.com
# itzod
# jetwin.com
# jigsaw
# justcoin.com
# koolova
# korbit.co.kr
# l1me_expl0it
# lakebtc.com
# laxotrade
# linode hack
# litebit.eu
# loanbase.com
# locky
# longtermpaying
# luno.com
# magic bitcoin doubler
# maicoin.com
# masterpool
# masterxchange.com
# matbea.com
# maxbtc
# mcxnow.com
# megabigpower
# mercadobitcoin.com.br
# mexbt.com
# middleearthmarketplace
# migpool
# minefield.bitcoinlab.org
# minerscenter.com
# minimalism10
# miningkings
# miniponzicoin
# mintpal.com
# mkalinin.ru
# mmm global
# moonbit.co.in
# mpex.co
# mt red
# mtgox
# mtgox hack
# multipool
# mybitcoin.com
# mybtccoin pool
# nanoindustryinv.com
# nemucod
# nexious
# nicehash hack
# nitrogensports.eu
# nmcbit
# noobcrypt
# notpetya
# nucleusmarket
# nullbyte
# oklink.com
# okminer
# okpool.top
# openponzi
# orderbook.net
# ozcoin
# p2pool.org
# pandoraopenmarket
# patel''s mining pool
# paxful.com
# payday
# paymium.com
# peerbet.org
# phash.io
# philadelphia
# phoenix
# picostocks
# picostocks hack
# pinballcoin.com
# playt.in
# pocketdice.io
# pocketrocketscasino.eu
# ponzi.io
# ponzi120
# ponzicoin
# ponzicoin.co
# poolin
# poolz 4 you
# popcorntime
# purse.io
# quadrigacx.com
# random6
# ransomplus
# ransomware
# rawpool.com
# razy
# rektlocker
# rigpool
# rockwellpartners
# rollin.io
# rush/sanction
# safedice.com
# sam
# samsam
# satoshi systems
# satoshibet.com
# satoshicircle.com
# satoshimines.com
# satoshiroulette.com
# sealswithclubs.eu
# secondstrade.com
# secretsuperstar
# sextortion excello
# sextortion talos
# shawnp0wers
# sheepmarketplace
# sigmapool.com
# silkroad2market
# silkroadmarketplace
# smallprofit
# smenarnabitcoin.cz
# spectrocoin.com
# st mining corp
# strongcoin.com-fee
# stupid
# suzukidice.com
# swcpoker.eu
# tangpool
# tbdice
# telco 214
# teslacrypt
# thundercrypt
# tiger
# tigerpool.net
# towerweb
# transactioncoinmining
# tricky''s btc pool
# triplemining
# trojan hack
# trump locker
# trusted business investments
# twelverized
# unknown ransomware
# unomp
# updown.bt
# urdubit.com-cold
# usecryptos.com
# vaultofsatoshi.com
# vaultoro.com
# venuslocker
# viabtc
# vic-socks.to
# vircurex hack
# vircurex.com
# virwox.com
# wannacry
# watchmybit.com
# waterhole
# weeklyponzi
# world-btc.online
# xbtc.exx.com&bw.com
# xorist
# xtplocker
# yabtcl.com
# yobit.net
# yourbtc.net
# zaif
# zaif hack
# zyka

# %% [markdown]
# ## Step #1b. Create unique labels

# %%
# map each label to unique label
label_uniqueLabel = dict() # map a label to a unique one
# founded manually
label_uniqueLabel['vircurex'] = 'vircurex.com'
label_uniqueLabel['btccpool'] = 'btcc pool'
label_uniqueLabel['btc guild'] = 'btcguild.com'
label_uniqueLabel['globev2'] = 'globe'
label_uniqueLabel['globev3'] = 'globe'
label_uniqueLabel['telco214'] = 'telco 214'
for label in sorted_labels: # all labels available, similars included
    if 'hack' in label.lower():
        label_uniqueLabel[label] = label        
    elif label not in label_uniqueLabel:
        root_found = False
        for root in labels_roots: # look for a possible root
            if label.startswith(root): # if found, use it and go to next label
                label_uniqueLabel[label] = root
                root_found = True
                break
        if not root_found:
            label_uniqueLabel[label] = label

# %%
# create mapping unique_label to category
uniqueLabel_category = dict()

# %%
# check if by using different versions of the same label, one entity is mapped into different categories
# create a set of categories for each unique label, then check its len
for label in label_category: # all labels, similars included
    unique_label = label_uniqueLabel[label]
    if unique_label not in uniqueLabel_category:
        uniqueLabel_category[unique_label] = set()
    uniqueLabel_category[unique_label].add(label_category[label])

# %% [markdown]
# # Step \#2. Manual entity check and cleaning

# %%
# check len of each set of categories for each unique label
# in len == 1: use that category, else manual fix
for unique_label in uniqueLabel_category:
    if len(uniqueLabel_category[unique_label]) > 1:
        print(uniqueLabel_category[unique_label], unique_label)
    else:
        uniqueLabel_category[unique_label] = list(uniqueLabel_category[unique_label])[0]

# %%
# Manual labeling
uniqueLabel_category['leancy'] = 'Ponzi Scheme'
uniqueLabel_category['cloudhashing'] = 'Miner'
uniqueLabel_category['btcguild.com'] = 'Miner'
uniqueLabel_category['polmine'] = 'Miner'
uniqueLabel_category['50btc'] = 'Miner'
uniqueLabel_category['deepbit'] = 'Miner'
uniqueLabel_category['xapo'] = 'Exchange'

# %%
# # some entities fall into the "old" or "other" categories, but we want to know what they were doing 
# # so google each of them and understand what they actually are/were doing
# for ul in uniqueLabel_category:
#     if uniqueLabel_category[ul] == 'Old/historic':
#         print(ul)

# %%
# manual work: checked each entity and decided what its category was
uniqueLabel_category['bitlaunder.com'] = 'Mixingservice'
uniqueLabel_category['bitnz.com'] = 'Exchange'
uniqueLabel_category['coinurl.com'] = 'Scam'
uniqueLabel_category['btcpop.co'] = 'Exchange'
uniqueLabel_category['gocelery.com'] = 'Exchange'
uniqueLabel_category['strongcoin.com'] = 'Walletprovider'
uniqueLabel_category['coinapult.com'] = 'Walletprovider'
uniqueLabel_category['doctordmarket'] = 'Marketplace'
uniqueLabel_category['paymium.com'] = 'Exchange'
uniqueLabel_category['germanplazamarket'] = 'Walletprovider'
uniqueLabel_category['greenroadmarket'] = 'Walletprovider'
uniqueLabel_category['epay.info'] = 'Exchange'
uniqueLabel_category['bitcoinwallet.com'] = 'Walletprovider'
uniqueLabel_category['oklink.com'] = 'Exchange'
uniqueLabel_category['helixmixer'] = 'Mixingservice'
uniqueLabel_category['holytransaction.com'] = 'Walletprovider'
uniqueLabel_category['coinkite.com'] = 'Walletprovider'
uniqueLabel_category['alphabaymarket'] = 'Marketplace'
uniqueLabel_category['nucleusmarket'] = 'Marketplace'
uniqueLabel_category['bitcoinfog'] = 'Mixingservice'
uniqueLabel_category['coinjar.com'] = 'Walletprovider'
uniqueLabel_category['cryptopay.me'] = 'Walletprovider'
uniqueLabel_category['coinpayments.net'] = 'Exchange'
uniqueLabel_category['cubits.com'] = 'Exchange'
uniqueLabel_category['cryptonator'] = 'Walletprovider'
uniqueLabel_category['blueskymarketplace'] = 'Marketplace'
uniqueLabel_category['blackbankmarket'] = 'Marketplace'
uniqueLabel_category['sheepmarketplace'] = 'Marketplace'
uniqueLabel_category['middleearthmarketplace'] = 'Marketplace'
uniqueLabel_category['pandoraopenmarket'] = 'Marketplace'
uniqueLabel_category['abraxasmarket'] = 'Marketplace'
uniqueLabel_category['evolutionmarket'] = 'Marketplace'
uniqueLabel_category['silkroad2market'] = 'Marketplace'
uniqueLabel_category['silkroadmarketplace'] = 'Marketplace'
uniqueLabel_category['agoramarket'] = 'Marketplace'
uniqueLabel_category['inputs.io'] = 'Walletprovider'
uniqueLabel_category['instawallet.org'] = 'Walletprovider'
uniqueLabel_category['betcoins.net'] = 'Gambling'
uniqueLabel_category['bitaces'] = 'Gambling'
uniqueLabel_category['pinballcoin.com'] = 'Gambling'
uniqueLabel_category['diceoncrack.com'] = 'Gambling'
uniqueLabel_category['btcdice.com'] = 'Gambling'
uniqueLabel_category['sealswithclubs.eu'] = 'Gambling'
uniqueLabel_category['updown.bt'] = 'Gambling'
uniqueLabel_category['betcoindice.tm'] = 'Gambling'
uniqueLabel_category['bitcoin-24.com'] = 'Exchange'
uniqueLabel_category['allcoin.com'] = 'Exchange'
uniqueLabel_category['justcoin.com'] = 'Exchange'
uniqueLabel_category['coin-swap.net'] = 'Exchange'
uniqueLabel_category['mcxnow.com'] = 'Scam'
uniqueLabel_category['mintpal.com'] = 'Scam'
uniqueLabel_category['bitmillions.com'] = 'Gambling'
uniqueLabel_category['mybitcoin.com'] = 'Walletprovider'
uniqueLabel_category['bitmit.net'] = 'Other'
uniqueLabel_category['cannabisroadmarket'] = 'Marketplace'
uniqueLabel_category['bitelfin.com'] = 'Gambling'
uniqueLabel_category['mtgox'] = 'Exchange'
uniqueLabel_category['bitfloor'] = 'Exchange'
uniqueLabel_category['vircurex'] = 'Exchange'
uniqueLabel_category['bips'] = 'Other'
uniqueLabel_category['picostocks'] = 'Exchange'
uniqueLabel_category['flexcoin'] = 'Wallet Service'
uniqueLabel_category['bitcoin-roulette.com'] = 'Gambling'
uniqueLabel_category['betcoins.net'] = 'Gambling'
uniqueLabel_category['betco.in'] = 'Gambling'
uniqueLabel_category['actioncrypto.com'] = 'Gambling'
uniqueLabel_category['allcrypt.com'] = 'Exchange'
uniqueLabel_category['bityes.com'] = 'Exchange'
uniqueLabel_category['vaultofsatoshi.com'] = 'Exchange'
uniqueLabel_category['crypto-trade.com'] = 'Exchange'
uniqueLabel_category['coin.mx'] = 'Exchange'
uniqueLabel_category['cryptorush.in'] = 'Exchange'
uniqueLabel_category['dagensia.eu'] = 'Exchange'
uniqueLabel_category['leancy'] = 'Scam'
uniqueLabel_category['comkort.com'] = 'Exchange'
uniqueLabel_category['dispenser.tf'] = 'Other'
uniqueLabel_category['playt.in'] = 'Other'
uniqueLabel_category['bitcoinica.com'] = 'Other'
uniqueLabel_category['coinvault'] = 'Walletprovider'
uniqueLabel_category['masterxchange.com'] = 'Exchange'
uniqueLabel_category['bitoomba.com'] = 'Scam'
uniqueLabel_category['dicebitco.in'] = 'Gambling'
uniqueLabel_category['ice-dice.com'] = 'Gambling'
uniqueLabel_category['pocketrocketscasino.eu'] = 'Gambling'
uniqueLabel_category['betsofbitco.in'] = 'Gambling'
uniqueLabel_category['chainroll.com'] = 'Gambling'
uniqueLabel_category['btcst.com-pirateat40'] = 'Scam'
uniqueLabel_category['coinmkt.com'] = 'Exchange'
uniqueLabel_category['minerscenter.com'] = 'Other'
uniqueLabel_category['coinhub.cz'] = 'Exchange'
uniqueLabel_category['btceur.eu'] = 'Other'
uniqueLabel_category['smenarnabitcoin.cz'] = 'Exchange'
uniqueLabel_category['brawker.com'] = 'Exchange'
uniqueLabel_category['suzukidice.com'] = 'Gambling'
uniqueLabel_category['everydice.com'] = 'Gambling'
uniqueLabel_category['cryptobounty.com'] = 'Other'
uniqueLabel_category['europex.eu'] = 'Other'
uniqueLabel_category['birwo.com-old'] = 'Gambling'
uniqueLabel_category['10xbitco.in'] = 'Scam'
uniqueLabel_category['admiralcoin.com'] = 'Gambling'
uniqueLabel_category['just-dice.com'] = 'Gambling'
uniqueLabel_category['dadice.com'] = 'Gambling'
uniqueLabel_category['mpex.co'] = 'Exchange'
uniqueLabel_category['btcexchange.ro'] = 'Exchange'
uniqueLabel_category['dgex.com'] = 'Exchange'
uniqueLabel_category['btct.com'] = 'Exchange'
uniqueLabel_category['babylonmarket'] = 'Marketplace'
uniqueLabel_category['cryptomine.io'] = 'Other'
uniqueLabel_category['cryptcominer.com'] = 'Other'
uniqueLabel_category['bitcoinica'] = 'Other'
uniqueLabel_category['bitcoinwebank.com'] = 'Other'
uniqueLabel_category['coin-sweeper.com'] = 'Other'
uniqueLabel_category['bitcash.cz'] = 'Other'
uniqueLabel_category['ponzicoin'] = 'Ponzi Scheme'

# %%
for ul in uniqueLabel_category:
    if uniqueLabel_category[ul] == 'Services/others':
        uniqueLabel_category[ul] = 'Other'
    elif uniqueLabel_category[ul] == 'Walletprovider':
        uniqueLabel_category[ul] = 'Wallet Service'
    elif uniqueLabel_category[ul] == 'Mixingservice':
        uniqueLabel_category[ul] = 'Mixing Service'

# %%
for ul in uniqueLabel_category:
    if not uniqueLabel_category[ul]:
        print(ul)
# Out:
# cryptolocker
# ponzicoin.co
# bylls.com
# securevpn.to
# vic-socks.to
# bitclix.com
# watchmybit.com
# coinworker.com
# coinbox.me
# btclend.org
# changetip.com
# genesis-mining.com
# cryptostocks.com
# strongcoin.com-fee
# bitbond.com
# loanbase.com
# purse.io
# faucetbox.com
# moonbit.co.in
# btcjam.com
# haobtc.com
# bitoex.com
# bitpay.com
# bitmain
# 7ev3n
# adamlocker
# alphabet
# angleware
# apt
# badblock
# badencrypt
# blackfeather
# btcware
# bucbi
# buddy
# chimera
# comradecircle
# cryptconsole
# cryptohitman
# cryptohost
# cryptosweettooth
# cryptotorlocker2015
# cryptxxx
# ctb-locker
# cybersplitter
# dmalocker
# domino
# doxware
# eda2
# exotic
# fakeglobe
# fantom
# firecrypt
# flyper
# globe
# globeimposter
# jigsaw
# koolova
# l1me_expl0it
# locky
# nemucod
# noobcrypt
# notpetya
# nullbyte
# payday
# philadelphia
# phoenix
# popcorntime
# random6
# ransomplus
# ransomware
# razy
# rektlocker
# rush/sanction
# sam
# samsam
# stupid
# teslacrypt
# thundercrypt
# towerweb
# trump locker
# unknown ransomware
# venuslocker
# wannacry
# xlocker
# xorist
# xtplocker
# zyka
# binance hack
# sextortion talos
# sextortion excello
# betco.in hack
# bitcoinica hack
# mtgox hack
# bitfloor hack
# 50btc hack
# vircurex hack
# inputs.io hack
# bitcash.cz hack
# bips hack
# picostocks hack
# flexcoin hack
# trojan hack
# linode hack
# dragonex hack
# zaif hack
# nicehash hack
# bitfinex hack
# bter hack
# nanoindustryinv.com
# grandagofinance
# cryptory
# minimalism10
# miniponzicoin
# 120cycle
# 10percentbtc
# btcgains
# ponzi.io
# laxotrade
# openponzi
# btc-doubler.us
# btc-doubler.com
# investorbitcoin.com
# ponzi120
# rockwellpartners
# twelverized
# cryptosx2
# 1hourbtc.pw
# bitcoindoubler.fund
# doublebitcoin.life
# bitcoincopy.site123.me
# bitcoinprofit2
# invest4profit
# 1getpaid.me
# igjam.com
# 7dayponzi
# world-btc.online
# bestdoubler.eu
# bitcoindoubler.prv.pl
# longtermpaying
# ebitinvest.com
# coindouble
# cryptosplit
# trusted business investments
# smallprofit
# magic bitcoin doubler
# coin-generator.net
# mmm global
# btc-flow
# weeklyponzi
# doublebot
# clearhash.net

# %%
set(uniqueLabel_category.values())
# Out:
# {'',
#  'Exchange',
#  'Gambling',
#  'Marketplace',
#  'Miner',
#  'Mixing Service',
#  'Other',
#  'Ponzi Scheme',
#  'Scam',
#  'Wallet Service'}

# %% [markdown]
# # Step \#3. Write files

# %%
with open('label_uniqueLabel.json', 'w') as fp:
    json.dump(label_uniqueLabel, fp)

# %%
with open('uniqueLabel_category.json', 'w') as fp:
    json.dump(uniqueLabel_category, fp)

# %%
for l in uniqueLabel_category:
    if uniqueLabel_category[l] == '':
        print(l)
# Out:
# cryptolocker
# ponzicoin.co
# bylls.com
# securevpn.to
# vic-socks.to
# bitclix.com
# watchmybit.com
# coinworker.com
# coinbox.me
# btclend.org
# changetip.com
# genesis-mining.com
# cryptostocks.com
# strongcoin.com-fee
# bitbond.com
# loanbase.com
# purse.io
# faucetbox.com
# moonbit.co.in
# btcjam.com
# haobtc.com
# bitoex.com
# bitpay.com
# bitmain
# 7ev3n
# adamlocker
# alphabet
# angleware
# apt
# badblock
# badencrypt
# blackfeather
# btcware
# bucbi
# buddy
# chimera
# comradecircle
# cryptconsole
# cryptohitman
# cryptohost
# cryptosweettooth
# cryptotorlocker2015
# cryptxxx
# ctb-locker
# cybersplitter
# dmalocker
# domino
# doxware
# eda2
# exotic
# fakeglobe
# fantom
# firecrypt
# flyper
# globe
# globeimposter
# jigsaw
# koolova
# l1me_expl0it
# locky
# nemucod
# noobcrypt
# notpetya
# nullbyte
# payday
# philadelphia
# phoenix
# popcorntime
# random6
# ransomplus
# ransomware
# razy
# rektlocker
# rush/sanction
# sam
# samsam
# stupid
# teslacrypt
# thundercrypt
# towerweb
# trump locker
# unknown ransomware
# venuslocker
# wannacry
# xlocker
# xorist
# xtplocker
# zyka
# binance hack
# sextortion talos
# sextortion excello
# betco.in hack
# bitcoinica hack
# mtgox hack
# bitfloor hack
# 50btc hack
# vircurex hack
# inputs.io hack
# bitcash.cz hack
# bips hack
# picostocks hack
# flexcoin hack
# trojan hack
# linode hack
# dragonex hack
# zaif hack
# nicehash hack
# bitfinex hack
# bter hack
# nanoindustryinv.com
# grandagofinance
# cryptory
# minimalism10
# miniponzicoin
# 120cycle
# 10percentbtc
# btcgains
# ponzi.io
# laxotrade
# openponzi
# btc-doubler.us
# btc-doubler.com
# investorbitcoin.com
# ponzi120
# rockwellpartners
# twelverized
# cryptosx2
# 1hourbtc.pw
# bitcoindoubler.fund
# doublebitcoin.life
# bitcoincopy.site123.me
# bitcoinprofit2
# invest4profit
# 1getpaid.me
# igjam.com
# 7dayponzi
# world-btc.online
# bestdoubler.eu
# bitcoindoubler.prv.pl
# longtermpaying
# ebitinvest.com
# coindouble
# cryptosplit
# trusted business investments
# smallprofit
# magic bitcoin doubler
# coin-generator.net
# mmm global
# btc-flow
# weeklyponzi
# doublebot
# clearhash.net

# %%
# read each file
# map label to unique label
# use only correct categories

for file in listdir(packs_folder):
    if file != 'blockchaininfo.yaml' and file[-3:] != 'csv':
        print(file)
        with open(packs_folder + file) as fp:
            data = yaml.safe_load(fp)
        for el in data['tags']:
            # clean label
            if 'label' in el:
                unique_label = label_uniqueLabel[el['label'].lower()]
                el['label'] = unique_label
            else:
                unique_label = data['label'].lower()
                data['label'] = data['label'].lower()
            # clean category
            if 'category' in el:
                el['category'] = uniqueLabel_category[unique_label]
        with open(packs_folder + file, 'w') as fp:
            yaml.dump(data, fp, default_flow_style=False)
# Out:
# walletexplorer.yaml
# richest_addresses.yaml
# ransomware.yaml
# binance.yaml
# binance_hack.yaml
# sextortion_talos.yaml
# miners.yaml
# demo.yaml
# sextortion_excello.yaml
# hacks.yaml
# ponzi_scheme.yaml

# %%
# update config.yaml
config_path = '../config.yaml'
with open(config_path) as fp:
    config = yaml.safe_load(fp)

# %%
for c in config['categories']:
    print(c)
# Out:
# Exchange
# Wallet Service
# Other
# Miner
# Marketplace
# Gambling
# Mixing Service

# %%
categories_list = ['Exchange', 'Wallet Service', 'Other', 'Miner', 'Marketplace', 'Gambling', 'Mixing Service', 'Organization', 'Scam', 'Sextortion', 'Ransomware', 'Ponzi Scheme', 'Hack']
config['categories'] = []
for c in categories_list:
    if c in set(uniqueLabel_category.values()):
        config['categories'].append(c)
config['categories'].append('Unspecified')

# %%
with open(config_path, 'w') as fp:
    yaml.dump(config, fp, default_flow_style=False)
